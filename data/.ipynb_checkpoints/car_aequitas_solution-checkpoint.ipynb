# %%
# imports
from aequitas.plotting import Plot
ap = Plot()
import pandas as pd

from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, label_binarize, LabelBinarizer
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("car.data")

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df =df.rename(columns={'vhigh':'buying',"vhigh.1":"maint","2":"doors","2.1":"persons","small":"lug_boot","low":"safety","unacc":"car"})

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety    car
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %%
df.car.value_counts()
# Out:
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: car, dtype: int64

# %%
df.car.replace(["good","vgood"], "acc", inplace=True)

# %%
df.car.value_counts()
# Out:
# unacc    1209
# acc       518
# Name: car, dtype: int64

# %%
# modify the data to make it a binary problem of acceptable or unacceptable car.
df.car.replace(["good","vgood"], "acc",inplace=True)

# %%
df.car.value_counts()
# Out:
# unacc    1209
# acc       518
# Name: car, dtype: int64

# %%
y = df.pop('car')
X = df

df.head()
# Out:
#   buying  maint doors persons lug_boot safety
# 0  vhigh  vhigh     2       2    small    med
# 1  vhigh  vhigh     2       2    small   high
# 2  vhigh  vhigh     2       2      med    low
# 3  vhigh  vhigh     2       2      med    med
# 4  vhigh  vhigh     2       2      med   high

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=23)
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)

# use this later to construct the dataFrame aequitas requires
df_aq = X_test.reset_index(drop=True).copy()

ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)
X_train = ohe.fit_transform(X_train.values)
X_test = ohe.transform(X_test.values)

lb = LabelBinarizer()
y_train = label_binarize(y_train.values, classes=['unacc','acc']).ravel()
y_test = label_binarize(y_test.values, classes=['unacc', 'acc']).ravel()
# Out:
# X_train shape:  (1295, 6)
# X_test shape:  (432, 6)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)

scores = lr.predict_proba(X_test)
pred = lr.predict(X_test)

f1 = f1_score(y_test, pred)
print(f"F1 score: {f1: 4f}")
# Out:
# F1 score:  0.916667

# %%
cm = confusion_matrix(y_test, pred, labels=[0,1])
ConfusionMatrixDisplay(cm, display_labels=["unacc","acc"]).plot()

# %%
# construct the dataframe that aequitas will use
df_aq['label_value'] = y_test
df_aq['score'] = pred
df_aq.head()
# Out:
#   buying  maint  doors persons lug_boot safety  label_value  score
# 0    med    low  5more       4    small    low            0      0
# 1   high  vhigh      3    more    small    med            0      0
# 2    low    low      4       4      med   high            1      1
# 3    low   high      3       4      med    med            1      1
# 4  vhigh   high  5more    more    small    low            0      0

# %%
pd.crosstab(df_aq.score, df_aq.persons)
# Out:
# persons    2   4  more
# score
# 0        148  77    85
# 1          0  60    62

# %%
pd.crosstab(df_aq.label_value, df_aq.persons)
# Out:
# persons        2   4  more
# label_value
# 0            148  79    87
# 1              0  58    60

# %%
# select predictions where
y_test_person_eq_2 = y_test[df_aq.loc[df_aq.persons == '2'].index]
y_pred_person_eq_2 = pred[df_aq.loc[df_aq.persons == '2'].index]

# %%
cm_person_eq_2 = confusion_matrix(y_test_person_eq_2, y_pred_person_eq_2, labels=[0,1])
ConfusionMatrixDisplay(cm_person_eq_2, display_labels=["unacc","acc"]).plot()

# %% [markdown]
# ## Run Aequitas

# %%
group = Group()
xtab, idxs = group.get_crosstabs(df_aq)
xtab.head()
# Out:
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  122         buying            high  0.896552
# 1         0      binary 0/1  122         buying             low  0.941176
# 2         0      binary 0/1  122         buying             med  0.945946
# 3         0      binary 0/1  122         buying           vhigh  0.944444
# 4         0      binary 0/1  122          maint            high  0.818182
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.917647  0.037037  0.212121  0.082353  0.103448  0.962963   0.787879  33
# 1  0.985075  0.029412  0.030303  0.014925  0.058824  0.970588   0.969697  33
# 2  0.971014  0.028986  0.054054  0.028986  0.054054  0.971014   0.945946  37
# 3  0.978495  0.010870  0.105263  0.021505  0.055556  0.989130   0.894737  19
# 4  0.977273  0.044444  0.100000  0.022727  0.181818  0.955556   0.900000  20
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  81  0.270492  0.289474   7   3  78  26               29               85
# 1  68  0.270492  0.326733   1   2  66  32               34               67
# 2  69  0.303279  0.349057   2   2  67  35               37               69
# 3  92  0.155738  0.171171   2   1  91  17               18               93
# 4  90  0.163934  0.181818   2   4  86  18               22               88
#
#    group_size  total_entities      prev
# 0         114             432  0.254386
# 1         101             432  0.336634
# 2         106             432  0.349057
# 3         111             432  0.162162
# 4         110             432  0.200000

# %%
bias = Bias()
bias_df = bias.get_disparity_major_group(xtab, original_df=df_aq, alpha=0.05,mask_significance=True )
bias_df.head()
# Out:
# get_disparity_major_group()
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  122         buying            high  0.896552
# 1         0      binary 0/1  122         buying             low  0.941176
# 2         0      binary 0/1  122         buying             med  0.945946
# 3         0      binary 0/1  122         buying           vhigh  0.944444
# 4         0      binary 0/1  122          maint            high  0.818182
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.917647  0.037037  0.212121  0.082353  0.103448  0.962963   0.787879  33
# 1  0.985075  0.029412  0.030303  0.014925  0.058824  0.970588   0.969697  33
# 2  0.971014  0.028986  0.054054  0.028986  0.054054  0.971014   0.945946  37
# 3  0.978495  0.010870  0.105263  0.021505  0.055556  0.989130   0.894737  19
# 4  0.977273  0.044444  0.100000  0.022727  0.181818  0.955556   0.900000  20
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  81  0.270492  0.289474   7   3  78  26               29               85
# 1  68  0.270492  0.326733   1   2  66  32               34               67
# 2  69  0.303279  0.349057   2   2  67  35               37               69
# 3  92  0.155738  0.171171   2   1  91  17               18               93
# 4  90  0.163934  0.181818   2   4  86  18               22               88
#
#    group_size  total_entities      prev  ppr_disparity  pprev_disparity  \
# 0         114             432  0.254386       1.000000         1.000000
# 1         101             432  0.336634       1.000000         1.128713
# 2         106             432  0.349057       1.121212         1.205832
# 3         111             432  0.162162       0.575758         0.591319
# 4         110             432  0.200000       1.000000         1.000000
#
#    precision_disparity  fdr_disparity  for_disparity  fpr_disparity  \
# 0             1.000000       1.000000       1.000000       1.000000
# 1             1.230769       0.142857       0.794118       0.181237
# 2             1.200624       0.254826       0.782609       0.351967
# 3             1.135628       0.496241       0.293478       0.261137
# 4             1.000000       1.000000       1.000000       1.000000
#
#    fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0       1.000000       1.000000       1.000000       1.000000
# 1       0.568627       1.049774       1.073479       1.007919
# 2       0.522523       1.055094       1.058157       1.008361
# 3       0.537037       1.053419       1.066308       1.027174
# 4       1.000000       1.000000       1.000000       1.000000
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0                high                  high                      high
# 1                high                  high                      high
# 2                high                  high                      high
# 3                high                  high                      high
# 4                high                  high                      high
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0                high                high                high
# 1                high                high                high
# 2                high                high                high
# 3                high                high                high
# 4                high                high                high
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0                high                high                high
# 1                high                high                high
# 2                high                high                high
# 3                high                high                high
# 4                high                high                high
#
#   npv_ref_group_value
# 0                high
# 1                high
# 2                high
# 3                high
# 4                high

# %%
fairness = Fairness()
fairness_df = fairness.get_group_value_fairness(bias_df)
fairness_df.head()
# Out:
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  122         buying            high  0.896552
# 1         0      binary 0/1  122         buying             low  0.941176
# 2         0      binary 0/1  122         buying             med  0.945946
# 3         0      binary 0/1  122         buying           vhigh  0.944444
# 4         0      binary 0/1  122          maint            high  0.818182
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.917647  0.037037  0.212121  0.082353  0.103448  0.962963   0.787879  33
# 1  0.985075  0.029412  0.030303  0.014925  0.058824  0.970588   0.969697  33
# 2  0.971014  0.028986  0.054054  0.028986  0.054054  0.971014   0.945946  37
# 3  0.978495  0.010870  0.105263  0.021505  0.055556  0.989130   0.894737  19
# 4  0.977273  0.044444  0.100000  0.022727  0.181818  0.955556   0.900000  20
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  81  0.270492  0.289474   7   3  78  26               29               85
# 1  68  0.270492  0.326733   1   2  66  32               34               67
# 2  69  0.303279  0.349057   2   2  67  35               37               69
# 3  92  0.155738  0.171171   2   1  91  17               18               93
# 4  90  0.163934  0.181818   2   4  86  18               22               88
#
#    group_size  total_entities      prev  ppr_disparity  pprev_disparity  \
# 0         114             432  0.254386       1.000000         1.000000
# 1         101             432  0.336634       1.000000         1.128713
# 2         106             432  0.349057       1.121212         1.205832
# 3         111             432  0.162162       0.575758         0.591319
# 4         110             432  0.200000       1.000000         1.000000
#
#    precision_disparity  fdr_disparity  for_disparity  fpr_disparity  \
# 0             1.000000       1.000000       1.000000       1.000000
# 1             1.230769       0.142857       0.794118       0.181237
# 2             1.200624       0.254826       0.782609       0.351967
# 3             1.135628       0.496241       0.293478       0.261137
# 4             1.000000       1.000000       1.000000       1.000000
#
#    fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0       1.000000       1.000000       1.000000       1.000000
# 1       0.568627       1.049774       1.073479       1.007919
# 2       0.522523       1.055094       1.058157       1.008361
# 3       0.537037       1.053419       1.066308       1.027174
# 4       1.000000       1.000000       1.000000       1.000000
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0                high                  high                      high
# 1                high                  high                      high
# 2                high                  high                      high
# 3                high                  high                      high
# 4                high                  high                      high
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0                high                high                high
# 1                high                high                high
# 2                high                high                high
# 3                high                high                high
# 4                high                high                high
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0                high                high                high
# 1                high                high                high
# 2                high                high                high
# 3                high                high                high
# 4                high                high                high
#
#   npv_ref_group_value Statistical Parity Impact Parity FDR Parity FPR Parity  \
# 0                high               True          True       True       True
# 1                high               True          True      False      False
# 2                high               True          True      False      False
# 3                high              False         False      False      False
# 4                high               True          True       True       True
#
#   FOR Parity FNR Parity TPR Parity  TNR Parity  NPV Parity Precision Parity  \
# 0       True       True       True        True        True             True
# 1      False      False       True        True        True             True
# 2      False      False       True        True        True             True
# 3      False      False       True        True        True             True
# 4       True       True       True        True        True             True
#
#   TypeI Parity TypeII Parity Equalized Odds Unsupervised Fairness  \
# 0         True          True           True                  True
# 1        False         False          False                  True
# 2        False         False          False                  True
# 3        False         False          False                 False
# 4         True          True           True                  True
#
#   Supervised Fairness
# 0                True
# 1               False
# 2               False
# 3               False
# 4                True

# %%
overall_fairness = fairness.get_overall_fairness(fairness_df)
print(overall_fairness)
# Out:
# {'Unsupervised Fairness': False, 'Supervised Fairness': False, 'Overall Fairness': False}

# %%
metrics = ['fpr', 'for','fnr']
disparity_metrics = [f"{metric}_disparity" for metric in metrics]

# %%
# Just as we discussed above, some statistics are zero or NAN
bias_df[["attribute_name", "attribute_value"] + metrics + disparity_metrics]
# Out:
#    attribute_name attribute_value       fpr       for       fnr  \
# 0          buying            high  0.082353  0.037037  0.103448
# 1          buying             low  0.014925  0.029412  0.058824
# 2          buying             med  0.028986  0.028986  0.054054
# 3          buying           vhigh  0.021505  0.010870  0.055556
# 4           maint            high  0.022727  0.044444  0.181818
# 5           maint             low  0.059701  0.015625  0.023256
# 6           maint             med  0.057971  0.000000  0.000000
# 7           maint           vhigh  0.022222  0.032967  0.157895
# 8           doors               2  0.058140  0.035714  0.187500
# 9           doors               3  0.040000  0.040000  0.100000
# 10          doors               4  0.011628  0.022989  0.054054
# 11          doors           5more  0.044776  0.000000  0.000000
# 12        persons               2  0.000000  0.000000       NaN
# 13        persons               4  0.088608  0.064935  0.086207
# 14        persons            more  0.057471  0.035294  0.050000
# 15       lug_boot             big  0.021739  0.000000  0.000000
# 16       lug_boot             med  0.046729  0.009709  0.023810
# 17       lug_boot           small  0.043478  0.059829  0.212121
# 18         safety            high  0.063291  0.075000  0.083333
# 19         safety             low  0.000000  0.000000       NaN
# 20         safety             med  0.072917  0.021978  0.043478
#
#     fpr_disparity  for_disparity  fnr_disparity
# 0        1.000000       1.000000       1.000000
# 1        0.181237       0.794118       0.568627
# 2        0.351967       0.782609       0.522523
# 3        0.261137       0.293478       0.537037
# 4        1.000000       1.000000       1.000000
# 5        2.626866       0.351562       0.127907
# 6        2.550725       0.000000       0.000000
# 7        0.977778       0.741758       0.868421
# 8        5.000000       1.553571       3.468750
# 9        3.440000       1.740000       1.850000
# 10       1.000000       1.000000       1.000000
# 11       3.850746       0.000000       0.000000
# 12            NaN            NaN            NaN
# 13      10.000000      10.000000            NaN
# 14      10.000000      10.000000            NaN
# 15       0.465217       0.000000       0.000000
# 16       1.000000       1.000000       1.000000
# 17       0.930435       6.162393       8.909091
# 18       1.000000       1.000000       1.000000
# 19       0.000000       0.000000            NaN
# 20       1.152083       0.293040       0.521739

# %%
# To avoid issues when plotting, add an epilon (0.000001) to cases where statistics are zero or NAN
eps = 0.000001
bias_df[disparity_metrics] = bias_df[disparity_metrics].fillna(0.0) + eps

# %%
bias_df[["attribute_name", "attribute_value"] + metrics + disparity_metrics]
# Out:
#    attribute_name attribute_value       fpr       for       fnr  \
# 0          buying            high  0.082353  0.037037  0.103448
# 1          buying             low  0.014925  0.029412  0.058824
# 2          buying             med  0.028986  0.028986  0.054054
# 3          buying           vhigh  0.021505  0.010870  0.055556
# 4           maint            high  0.022727  0.044444  0.181818
# 5           maint             low  0.059701  0.015625  0.023256
# 6           maint             med  0.057971  0.000000  0.000000
# 7           maint           vhigh  0.022222  0.032967  0.157895
# 8           doors               2  0.058140  0.035714  0.187500
# 9           doors               3  0.040000  0.040000  0.100000
# 10          doors               4  0.011628  0.022989  0.054054
# 11          doors           5more  0.044776  0.000000  0.000000
# 12        persons               2  0.000000  0.000000       NaN
# 13        persons               4  0.088608  0.064935  0.086207
# 14        persons            more  0.057471  0.035294  0.050000
# 15       lug_boot             big  0.021739  0.000000  0.000000
# 16       lug_boot             med  0.046729  0.009709  0.023810
# 17       lug_boot           small  0.043478  0.059829  0.212121
# 18         safety            high  0.063291  0.075000  0.083333
# 19         safety             low  0.000000  0.000000       NaN
# 20         safety             med  0.072917  0.021978  0.043478
#
#     fpr_disparity  for_disparity  fnr_disparity
# 0        1.000001       1.000001       1.000001
# 1        0.181238       0.794119       0.568628
# 2        0.351968       0.782610       0.522524
# 3        0.261138       0.293479       0.537038
# 4        1.000001       1.000001       1.000001
# 5        2.626867       0.351563       0.127908
# 6        2.550726       0.000001       0.000001
# 7        0.977779       0.741759       0.868422
# 8        5.000001       1.553572       3.468751
# 9        3.440001       1.740001       1.850001
# 10       1.000001       1.000001       1.000001
# 11       3.850747       0.000001       0.000001
# 12       0.000001       0.000001       0.000001
# 13      10.000001      10.000001       0.000001
# 14      10.000001      10.000001       0.000001
# 15       0.465218       0.000001       0.000001
# 16       1.000001       1.000001       1.000001
# 17       0.930436       6.162394       8.909092
# 18       1.000001       1.000001       1.000001
# 19       0.000001       0.000001       0.000001
# 20       1.152084       0.293041       0.521740

# %%
disparity_tolerance = 1.25
# Deprecated function summary()
# ap.summary(bias_df, metrics, fairness_threshold=disparity_tolerance)

# Aequitas Fairness() class provides a few functions that provide a high level summary of fairness and disparity, such as 
# plot_fairness_group()
# plot_fairness_group_all()
# plot_fairness_disparity()
# plot_fairness_disparity_all()
# plot_disparity()
# See some example here: https://github.com/dssg/aequitas/blob/master/docs/source/examples/compas_demo.ipynb 
p = ap.plot_disparity_all(bias_df, metrics=['precision_disparity'], significance_alpha=0.05)
